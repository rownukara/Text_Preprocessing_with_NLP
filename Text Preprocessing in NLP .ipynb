# %% [markdown]
# Text Preprocessing: lowercasing , stopword removal, regular expression(regex), tokenization, stemming,lemmatization,n-grams

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ASUS'

# %% [markdown]
# LOWERCASING WORDS

# %%
#LOWERCASING TEXT
sentence="Her cat's name is Luna"
sentence_lower= sentence.lower()
print(sentence_lower)
# Out:
# her cat's name is luna

# %%
sentence_list = ['Could you pass me the TV remote?', 
                 'It is IMPOSSIBLE to find this hotel', 
                 'Want to go for dinner on Tuesday?']
print(sentence_list)
# Out:
# ['Could you pass me the TV remote?', 'It is IMPOSSIBLE to find this hotel', 'Want to go for dinner on Tuesday?']

# %%
sentence_list_lowercase=[]
for i in sentence_list:
    sentence_list_lowercase.append(i.lower())
print(sentence_list_lowercase)
# Out:
# ['could you pass me the tv remote?', 'it is impossible to find this hotel', 'want to go for dinner on tuesday?']

# %%
sentence_list_lowercase_comphaension=[x.lower() for x in sentence_list]
print(sentence_list_lowercase_comphaension)
# Out:
# ['could you pass me the tv remote?', 'it is impossible to find this hotel', 'want to go for dinner on tuesday?']

# %% [markdown]
# STOP WORDS REMOVING

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
english_stopwords=stopwords.words('english')
print(english_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
english_stopwords.append('did')
english_stopwords.remove('a')

# %%
sentence = "it was too far to go to the shop and he did not want her to walk"

# %%
sentence_with_no_stopwords=' '.join([x for x in sentence.split() if x not in (english_stopwords)])
print(sentence_with_no_stopwords)
# Out:
# far go shop want walk

# %% [markdown]
# Regular Expressions(Regex)

# %%
#raw string
my_folder = "C:\desktop\notes"
print(my_folder)
r_my_folder=r"C:\desktop\notes"
print(r_my_folder)
# Out:
# C:\desktop
# otes
# C:\desktop\notes

# %%
#re.search
import re

# %%
result_search = re.search("pattern", r"string containing the pattern")
print(result_search)
# Out:
# <re.Match object; span=(22, 29), match='pattern'>

# %%
result_search = re.search("pattern",r"the phrase to find isn't in this string")
print(result_search) # returns None
# Out:
# None

# %%
#re.sub()
string = r"sara was able to help me find the items i needed quickly"
new_string = re.sub(r"sara", r"sarah", string) # replace the incorrect spelling of sarah
print(new_string)
# Out:
# sarah was able to help me find the items i needed quickly

# %%
#Regex Syntax
customer_reviews = ['sam was a great help to me in the store', 
                    'the cashier was very rude to me, I think her name was eleanor', 
                    'amazing work from sadeen!', 
                    'sarah was able to help me find the items i needed quickly', 
                    'lucy is such a great addition to the team', 
                    'great service from sara she found me what i wanted'
                   ]

# %%
#pubcuation
customer_reviews_dict=[]
pattern= r"[^\w\s]"
for i in customer_reviews:
    no_punct_string=re.sub(pattern,"",i)
    customer_reviews_dict.append(no_punct_string)
print(customer_reviews_dict)
# Out:
# ['sam was a great help to me in the store', 'the cashier was very rude to me I think her name was eleanor', 'amazing work from sadeen', 'sarah was able to help me find the items i needed quickly', 'lucy is such a great addition to the team', 'great service from sara she found me what i wanted']

# %% [markdown]
# TOKENIZATION

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize , sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
sentences = "Her cat's name is Luna. Her dog's name is max"
sent_tokenize(sentences)
# Out:
# ["Her cat's name is Luna.", "Her dog's name is max"]

# %%
sentences = "Her cat's name is Luna."
word_tokenize(sentences)
# Out:
# ['Her', 'cat', "'s", 'name', 'is', 'Luna', '.']

# %%
sentence_2 = "Her cat's name is Luna and her dog's name is max"
word_tokenize(sentence_2)
# Out:
# ['Her',
#  'cat',
#  "'s",
#  'name',
#  'is',
#  'Luna',
#  'and',
#  'her',
#  'dog',
#  "'s",
#  'name',
#  'is',
#  'max']

# %% [markdown]
# STEMMING

# %%
from nltk.stem import PorterStemmer

# %%
ps=PorterStemmer()
connect_tokens=['connecting', 'connected', 'connectivity', 'connect', 'connects']
for i in connect_tokens:
    print(i," :", ps.stem(i))
# Out:
# connecting  : connect
# connected  : connect
# connectivity  : connect
# connect  : connect
# connects  : connect

# %%
learn_tokens=['learned', 'learning', 'learn', 'learns', 'learner', 'learners']
for i in learn_tokens:
    print(i, ":", ps.stem(i))
# Out:
# learned : learn
# learning : learn
# learn : learn
# learns : learn
# learner : learner
# learners : learner

# %%
likes_tokens = ['likes', 'better', 'worse']
for i in likes_tokens:
    print(i, ":", ps.stem(i))
# Out:
# likes : like
# better : better
# worse : wors

# %% [markdown]
# LEMMATIZATION

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...

# %%
lemmatizer = WordNetLemmatizer()

# %%
for t in connect_tokens:
    print(t, " : ", lemmatizer.lemmatize(t))

for t in learn_tokens:
    print(t, " : ", lemmatizer.lemmatize(t))

for t in likes_tokens:
    print(t, " : ", lemmatizer.lemmatize(t))
# Out:
# connecting  :  connecting
# connected  :  connected
# connectivity  :  connectivity
# connect  :  connect
# connects  :  connects
# learned  :  learned
# learning  :  learning
# learn  :  learn
# learns  :  learns
# learner  :  learner
# learners  :  learner
# likes  :  like
# better  :  better
# worse  :  worse

# %% [markdown]
# N-GRAMS

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# %%
tokens = ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']
print(tokens)
# Out:
# ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']

# %%
# unigrams: n=1
unigrams =(pd.Series(nltk.ngrams(tokens,1)).value_counts())
print(unigrams)
# Out:
# (to,)          7
# (of,)          6
# (the,)         4
# (in,)          4
# (learning,)    3
#               ..
# (humans,)      1
# (rise,)        1
# (advent,)      1
# (deep,)        1
# (come,)        1
# Name: count, Length: 79, dtype: int64

# %%
unigrams[0:10].sort_values().plot.barh(color="lightsalmon", width=.8, figsize=(12,8))
plt.title("10 most frequent occuring Unigrams")
plt.xlabel("Unigram")
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %%
bigrams=(pd.Series(nltk.ngrams(tokens,2)).value_counts())
print(bigrams)
# Out:
# (that, were)             2
# (the, rise)              1
# (increasingly, being)    1
# (ai, is)                 1
# (result, ai)             1
#                         ..
# (tasks, that)            1
# (complex, tasks)         1
# (perform, complex)       1
# (to, perform)            1
# (to, come)               1
# Name: count, Length: 105, dtype: int64

# %%
trigrams=(pd.Series(nltk.ngrams(tokens,3)).value_counts())
print(trigrams)
# Out:
# (the, rise, of)              1
# (even, more, powerful)       1
# (ai, is, increasingly)       1
# (result, ai, is)             1
# (a, result, ai)              1
#                             ..
# (that, were, once)           1
# (tasks, that, were)          1
# (complex, tasks, that)       1
# (perform, complex, tasks)    1
# (years, to, come)            1
# Name: count, Length: 105, dtype: int64
